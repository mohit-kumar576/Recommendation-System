# %% [markdown]
# <a href="https://colab.research.google.com/github/mohit-kumar576/Recommendation-System/blob/main/Python_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to python programming")
# Out:
# Welcome to python programming

# %% [markdown]
# ### **Input and Ouput in Python**

# %%
# single varialbe
a = input ("Enter your name")
print (a)
print ("My Name is",a)
# Out:
# Enter your name Mohit Kumar
#  Mohit Kumar
# My Name is  Mohit Kumar

# %%
# multiple input using
x,y,z = input ("Enter your value").split()
print("Total number of flower",x)
print("No. of roses",y)
print("No. of marigold",z)
# Out:
# Enter your value 60 70 80
# Total number of flower 60
# No. of roses 70
# No. of marigold 80

# %%
name,degree,current_job = input("enter your value").split()
print("My name is",name)
print("I have completed",degree)
print("Working as",current_job)
# Out:
# enter your value Pankaj B.Com Business_Advisor
# My name is Pankaj
# I have completed B.Com
# Working as Business_Advisor

# %% [markdown]
# # **Keyword in python**

# %%
import keyword
print("The number keyword exist in python")
print(keyword.kwlist)
# Out:
# The number keyword exist in python
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %% [markdown]
# # **Data types in python**

# %%
# Integer type data
b = 76
print (b)
print(type(b))
# Out:
# 76
# <class 'int'>

# %%
# Float type data
c = 98.89
print(c)3
print(type(c))
# Out:
# 98.89
# <class 'float'>

# %%
# Complex number data type
d = 6 + 7j
print(d)
print(type(d))
# Out:
# (6+7j)
# <class 'complex'>

# %%
# String data type
m = "Data Anyalst"
print(m)
print(type(m))

# Indexing
print(m[0])
print(m[4])
print(m[5])
# Out:
# Data Anyalst
# <class 'str'>
# D
#
# A
